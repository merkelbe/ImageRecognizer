# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import google_image_downloader

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
PATH = "images/"
sz = 224

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.backends.cudnn.enabled
# Out:
# True

# %%
os.listdir(f'{PATH}valid')
# Out:
# ['cats', 'dogs']

# %%
files = os.listdir(f'{PATH}valid/cats')[:5]

# %%
files
# Out:
# ['cat.101.jpg', 'cat.112.jpg', 'cat.113.jpg', 'cat.118.jpg', 'cat.119.jpg']

# %%
img = plt.imread(f'{PATH}valid/cats/{files[0]}')
plt.imshow(img)

# %%
arch=resnet34

# %%
data = ImageClassifierData.from_paths(PATH,tfms = tfms_from_model(arch,sz))

# %%
learn = ConvLearner.pretrained(arch,data,precompute=True)

# %%
learn.fit(0.01,4)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=4), HTML(value='')))
# [0.      0.35167 0.18654 0.94138]
# [1.      0.23143 0.15925 0.96307]
# [2.      0.17475 0.15607 0.95994]
# [3.      0.1441  0.15477 0.95994]

# %%
learn.save("cat_dog_224")

# %%
learn = ConvLearner.pretrained(arch,data,precompute=True)

# %%
lrf = learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# [  0.        0.94321 161.00108   0.94138]

# %%
learn.sched.plot_lr()

# %%
learn.sched.plot()

# %%
learn.fit(0.1,2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=2), HTML(value='')))
# [0.      0.05742 0.44127 0.94763]
# [1.      0.08073 0.39579 0.95701]

# %%
learn.precompute=False

# %%
learn.fit(0.1,5,cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=5), HTML(value='')))
# [0.      0.07576 0.46286 0.94138]
# [1.      0.05237 0.48228 0.95388]
# [2.      0.03753 0.54101 0.9447 ]
# [3.      0.03375 0.50201 0.95994]
# [4.      0.03417 0.52992 0.93845]

# %%
learn.save("cat_dog_224")

# %%
learn.load("cat_dog_224")

# %%
learn.freeze()

# %%
learn.fit(0.01,3,cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# [0.      0.0362  0.53326 0.93845]
# [1.      0.02746 0.50838 0.94157]
# [2.      0.03073 0.50574 0.94157]

# %%
learn.fit(0.01,3,cycle_len=1,cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# [0.      0.01589 0.50299 0.94157]
# [1.      0.01354 0.51319 0.94157]
# [2.      0.01623 0.51215 0.93845]
# [3.      0.01585 0.50937 0.95682]
# [4.      0.01629 0.50709 0.95076]
# [5.      0.01686 0.51186 0.95076]
# [6.      0.02603 0.51455 0.94157]

# %%
log_preds,y = learn.TTA()
probs = np.exp(log_preds)
accuracy(log_preds,y), metrics.log_loss(y, probs)
# Out:
# (0.9515570934256056, 0.3851693586826403)
